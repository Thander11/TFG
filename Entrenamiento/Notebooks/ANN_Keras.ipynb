# %% [markdown]
# # Importación de librerías

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from google.colab import drive

print("Librerías cargadas correctamente.")
# Out:
# Librerías cargadas correctamente.

# %% [markdown]
# # Carga de archivos (.txt) y etiquetado

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# --- CONFIGURACIÓN DE RUTAS ---
bueno_dir = '/content/drive/MyDrive/Colab Notebooks/BUENO'
malo_dir = '/content/drive/MyDrive/Colab Notebooks/MALO'

X_features = []
y_labels = []

def cargar_sustancias(ruta_carpeta, etiqueta):
    conteo = 0
    for archivo in os.listdir(ruta_carpeta):
        if archivo.endswith(".txt"):
            ruta_completa = os.path.join(ruta_carpeta, archivo)
            try:
                # Usamos pandas.read_csv, que es más robusto para archivos con decimales ','
                # y permite saltar filas con 'skiprows'. Cambiamos 'sep' a espacio.
                datos_df = pd.read_csv(ruta_completa, sep=' ', decimal=',', skiprows=1, header=None)

                # Convertir todas las columnas a numérico, forzando los errores a NaN
                datos_df = datos_df.apply(pd.to_numeric, errors='coerce')

                # Convertir a numpy y aplanar
                datos = datos_df.values.flatten()

                # DEBUG: Imprimir información sobre el archivo y si está todo NaN
                if np.all(np.isnan(datos)):
                    print(f"Advertencia: Archivo '{archivo}' de la carpeta '{os.path.basename(ruta_carpeta)}' contiene solo NaNs después del procesamiento y será ignorado.")
                else:
                    X_features.append(datos)
                    y_labels.append(etiqueta)
                    conteo += 1
            except Exception as e:
                print(f"Error en {archivo} de la carpeta '{os.path.basename(ruta_carpeta)}': {e}")
    return conteo

# Cargar datos
n_buenos = cargar_sustancias(bueno_dir, 1) # 1 para Sustancia Correcta
n_malos = cargar_sustancias(malo_dir, 0)   # 0 para Otras Sustancias

# --- MODIFICACIÓN PARA MANEJAR LARGOS VARIABLES Y RELLENAR ---
# Solo procesar si X_features no está vacío
if X_features:
    # Encontrar la longitud máxima entre todos los arrays cargados
    max_len = max(len(x) for x in X_features)

    # Rellenar (pad) los arrays más cortos con NaN para que todos tengan la misma longitud
    padded_X_features = []
    for x in X_features:
        if len(x) < max_len:
            # Crear un array de NaN para rellenar
            padding = np.full(max_len - len(x), np.nan)
            padded_X_features.append(np.concatenate((x, padding)))
        else:
            padded_X_features.append(x)
    X = np.array(padded_X_features)
else:
    X = np.array([]) # Si no hay datos, X será un array vacío
    print("Advertencia: No se cargaron datos en X_features.")

y = np.array(y_labels)

print(f"Finalizado: {n_buenos} archivos BUENOS y {n_malos} archivos MALOS cargados.")
print(f"Forma de la matriz X: {X.shape}")
# Out:
# Finalizado: 38 archivos BUENOS y 38 archivos MALOS cargados.
# Forma de la matriz X: (76, 2100)

# %% [markdown]
# # División del Dataset (Train, Val, Test) y Escalado

# %%
# 1. Separar un 20% para el Test final
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# 2. Imputar los valores NaN antes de escalar
# Usamos la media de cada columna del conjunto de entrenamiento para imputar.
# Cambiamos la estrategia a 'constant' para asegurar que todos los NaN sean tratados,
# incluso en columnas completamente NaN.
imputer = SimpleImputer(strategy='constant', fill_value=0) # Rellenar con 0

X_train_val_imputed = imputer.fit_transform(X_train_val)
X_test_imputed = imputer.transform(X_test) # Usar el imputer entrenado con el conjunto de entrenamiento

# 3. Escalar los datos (Fundamental para una ANN)
scaler = StandardScaler()
X_train_val_scaled = scaler.fit_transform(X_train_val_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

print(f"Datos listos.")
print(f"Entrenamiento + Validación: {X_train_val_scaled.shape[0]} muestras")
print(f"Prueba final (Test): {X_test_scaled.shape[0]} muestras")
print("Medias:", scaler.mean_)
print("Desviaciones:", np.sqrt(scaler.var_))
# Out:
# Datos listos.
# Entrenamiento + Validación: 60 muestras
# Prueba final (Test): 16 muestras
# Medias: [1.24433333e+03 3.13957500e+04 2.48333333e+00 ... 2.88333333e+00
#  3.63229144e+05 9.83333333e-01]
# Desviaciones: [3.97673512e+02 1.14787644e+03 6.45282023e-01 ... 1.09683889e+00
#  1.55968400e+05 1.28019096e-01]

# %% [markdown]
# # Definición y Entrenamiento de la ANN

# %%
# Definir la estructura de la red
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train_val_scaled.shape[1],)),
    Dropout(0.2), # Ayuda a evitar el sobreajuste
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid') # Salida binaria (0 a 1)
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Configurar parada temprana
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Entrenar (usamos el 20% de lo restante para validación)
print("Iniciando entrenamiento...")

history = model.fit(
    X_train_val_scaled, y_train_val,
    epochs=50,
    batch_size=5,
    validation_split=0.2, # Divide internamente el set de entrenamiento
    callbacks=[early_stop],
    verbose=1
)

print("Entrenamiento finalizado")
# Out:
# Iniciando entrenamiento...
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.7843 - loss: 0.5497 - val_accuracy: 0.9167 - val_loss: 0.2685
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8279 - loss: 0.2694 - val_accuracy: 0.9167 - val_loss: 0.1956
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8206 - loss: 0.2775 - val_accuracy: 0.9167 - val_loss: 0.1731
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8496 - loss: 0.1935 - val_accuracy: 0.9167 - val_loss: 0.2189
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8150 - loss: 0.2708 - val_accuracy: 0.9167 - val_loss: 0.1550
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8858 - loss: 0.2012 - val_accuracy: 0.8333 - val_loss: 0.1530
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9518 - loss: 0.1009 - val_accuracy: 0.9167 - val_loss: 0.1806
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0791 - val_accuracy: 0.8333 - val_loss: 0.2134
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9592 - loss: 0.0948 - val_accuracy: 0.8333 - val_loss: 0.2165
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9756 - loss: 0.1098 - val_accuracy: 0.8333 - val_loss: 0.2049
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9827 - loss: 0.0489 - val_accuracy: 0.9167 - val_loss: 0.1515
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0897 - val_accuracy: 0.9167 - val_loss: 0.2287
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9919 - loss: 0.0322 - val_accuracy: 0.9167 - val_loss: 0.2253
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0396 - val_accuracy: 0.9167 - val_loss: 0.2395
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 0.9167 - val_loss: 0.2514
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.8333 - val_loss: 0.2298
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.8333 - val_loss: 0.2427
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.8333 - val_loss: 0.2895
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9448 - loss: 0.0986 - val_accuracy: 0.9167 - val_loss: 0.2434
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9630 - loss: 0.0484 - val_accuracy: 0.9167 - val_loss: 0.2773
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.8333 - val_loss: 0.2699
# Entrenamiento finalizado

# %% [markdown]
# # Evaluación y Resultados

# %%
# Evaluar con el conjunto de Test
loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f"--- RESULTADOS FINALES ---")
print(f"Precisión en Test (Accuracy): {accuracy*100:.2f}%")

# Gráfico de la evolución del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión del Modelo')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss) del Modelo')
plt.legend()
plt.show()
# Out:
# --- RESULTADOS FINALES ---
# Precisión en Test (Accuracy): 93.75%

# %%
# Hacer predicciones en el conjunto de prueba
y_pred_proba = model.predict(X_test_scaled)
y_pred = (y_pred_proba > 0.5).astype(int) # Convertir probabilidades a clases binarias (0 o 1)

# Generar la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

print("Matriz de Confusión:")
print(cm)

# Visualizar la matriz de confusión (opcional)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Malo (0)', 'Bueno (1)'],
            yticklabels=['Malo (0)', 'Bueno (1)'])
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.title('Matriz de Confusión')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# Matriz de Confusión:
# [[8 0]
#  [1 7]]

# %% [markdown]
# # Guardar el modelo

# %%
# Definir la ruta para guardar el modelo
model_save_path = '/content/drive/MyDrive/Colab Notebooks/modelo_hachis_keras.keras'

# Guardar el modelo
model.save(model_save_path)

print(f"Modelo guardado exitosamente en: {model_save_path}")
# Out:
# Modelo guardado exitosamente en: /content/drive/MyDrive/Colab Notebooks/modelo_hachis_keras.keras

# %% [markdown]
# ### Conversión y Guardado del Modelo a TensorFlow Lite (TFLite)

# %%
import tensorflow as tf

# Cargar el modelo Keras guardado
model_load_path = '/content/drive/MyDrive/Colab Notebooks/modelo_hachis_keras.keras'
model = tf.keras.models.load_model(model_load_path)

# Inicializar el convertidor de TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Convertir el modelo
tflite_model = converter.convert()

# Definir la ruta para guardar el modelo TFLite
tflite_model_save_path = '/content/drive/MyDrive/Colab Notebooks/modelo_hachis.tflite'

# Guardar el modelo TFLite en el disco
with open(tflite_model_save_path, 'wb') as f:
    f.write(tflite_model)

print(f"Modelo TensorFlow Lite guardado exitosamente en: {tflite_model_save_path}")
# Out:
# Saved artifact at '/tmp/tmpupnytail'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 2100), dtype=tf.float32, name='input_layer_5')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139265191707472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139263619632592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139263619637200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139263619631632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139263619636240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139263619640080: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modelo TensorFlow Lite guardado exitosamente en: /content/drive/MyDrive/Colab Notebooks/modelo_hachis.tflite
